# %%
from __future__ import absolute_import
from __future__ import print_function
from __future__ import division
from __future__ import unicode_literals

# %matplotlib inline
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.contrib import learn
from sklearn.metrics import mean_squared_error
from lstm import generate_data, lstm_model, load_csvdata
import dateutil.parser
import datetime
import matplotlib.dates as mdates

import json
from os import listdir, getcwd
from os.path import isfile, join
import rpy2.robjects as ro
from rpy2.robjects import numpy2ri
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-692cec654b40> in <module>()
#      19 from os import listdir, getcwd
#      20 from os.path import isfile, join
# ---> 21 import rpy2.robjects as ro
#      22 from rpy2.robjects import numpy2ri
#
# /home/u5963436/anaconda2/lib/python2.7/site-packages/rpy2/robjects/__init__.py in <module>()
#      14 import itertools
#      15 from datetime import datetime
# ---> 16 import rpy2.rinterface as rinterface
#      17 import rpy2.rlike.container as rlc
#      18
#
# /home/u5963436/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py in <module>()
#      90 del(os)
#      91
# ---> 92 from rpy2.rinterface._rinterface import (baseenv,
#      93                                          emptyenv,
#      94                                          endr,
#
# ImportError: dlopen: cannot load any more object with static TLS

# %%
LOG_DIR = './ops_logs/lstm_popularity'
TIMESTEPS = 10
RNN_LAYERS = [{'num_units': 5}]
DENSE_LAYERS = [10, 10]
TRAINING_STEPS = 100000
BATCH_SIZE = 100
PRINT_STEPS = TRAINING_STEPS / 100

# %% [markdown]
# # Load The Data as CSV
# This is QCLCD data for PDX. It is waht will be used to train the model.

# %%
# Read files

mypath = getcwd()+"/data/tweet_youtube"
onlyfiles = [ join(mypath, f) for f in listdir(mypath) if isfile(join(mypath, f))]
tweets_time = {}
for f in onlyfiles:
    ro.r['load'](f,ro.globalenv)

shares = ro.globalenv[str('data')].rx2("numShare")
views = ro.globalenv[str('data')].rx2("dailyViewcount")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-83b6375e8ea6> in <module>()
#       6 tweets_time = {}
#       7 for f in onlyfiles:
# ----> 8     ro.r['load'](f,ro.globalenv)
#       9
#      10 shares = ro.globalenv[str('data')].rx2("numShare")
#
# NameError: name 'ro' is not defined

# %%
s_i = shares[2][:120]
v_i = views[2][:120]

data_sv = pd.DataFrame([s_i,v_i])
print(data_sv)
#X, y = load_csvdata(data_sv, TIMESTEPS, seperate=False)

# %% [markdown]
# # Run The Model and Fit Predictions

# %%
regressor = learn.Estimator(model_fn=lstm_model(TIMESTEPS, RNN_LAYERS, DENSE_LAYERS),
                           model_dir=LOG_DIR)
# Out:
# WARNING:tensorflow:Using default config.

# %%
# create a lstm instance and validation monitor
y_val = np.array([ [i[0]] for i in y['val']])
y_train = np.array([ [i[0]] for i in y['train']])

validation_monitor = learn.monitors.ValidationMonitor(X['val'], y_val,
                                                     every_n_steps=PRINT_STEPS,
                                                     early_stopping_rounds=1000)
regressor.fit(X['train'], y_train,
              monitors=[validation_monitor],
              batch_size=BATCH_SIZE,
              steps=TRAINING_STEPS)

predicted = regressor.predict(X['test'])
# Out:
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 10, 2), dtype=float32), required signatures: TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(10), Dimension(2)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=float32), required signatures: TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(2)]), is_sparse=False).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-3788c5f3bd1c> in <module>()
#       9               monitors=[validation_monitor],
#      10               batch_size=BATCH_SIZE,
# ---> 11               steps=TRAINING_STEPS)
#      12
#      13 predicted = regressor.predict(X['test'])
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     217                              steps=steps,
#     218                              monitors=monitors,
# --> 219                              max_steps=max_steps)
#     220     logging.info('Loss for final step: %s.', loss)
#     221     return self
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in _train_model(self, input_fn, steps, feed_fn, init_op, init_feed_fn, init_fn, device_fn, monitors, log_every_steps, fail_on_nan_loss, max_steps)
#     476       global_step = contrib_framework.create_global_step(g)
#     477       features, targets = input_fn()
# --> 478       self._check_inputs(features, targets)
#     479       train_op, loss_op = self._get_train_ops(features, targets)
#     480
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in _check_inputs(self, features, targets)
#     436           raise ValueError('Targets are incompatible with given information. '
#     437                            'Given targets: %s, required signatures: %s.' %
# --> 438                            (str(targets), str(self._targets_info)))
#     439       else:
#     440         self._targets_info = tensor_signature.create_signatures(targets)
#
# ValueError: Targets are incompatible with given information. Given targets: Tensor("output:0", shape=(?,), dtype=float32), required signatures: TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(2)]), is_sparse=False).

# %%
#not used in this example but used for seeing deviations
rmse = np.sqrt(((predicted - y['test']) ** 2).mean(axis=0))

score = mean_squared_error(predicted, y['test'])
print ("MSE: %f" % score)
# Out:
# MSE: 1.157164

# %%
# plot the data
all_dates = data_weather.index.get_values()

fig, ax = plt.subplots(1)
fig.autofmt_xdate()

predicted_values = predicted.flatten() #already subset
predicted_dates = all_dates[len(all_dates)-len(predicted_values):len(all_dates)]
predicted_series = pd.Series(predicted_values, index=predicted_dates)
plot_predicted, = ax.plot(predicted_series, label='predicted (c)')

test_values = y['test'].flatten()
test_dates = all_dates[len(all_dates)-len(test_values):len(all_dates)]
test_series = pd.Series(test_values, index=test_dates)
plot_test, = ax.plot(test_series, label='2015 (c)')

xfmt = mdates.DateFormatter('%b %d %H')
ax.xaxis.set_major_formatter(xfmt)

# ax.fmt_xdata = mdates.DateFormatter('%Y-%m-%d %H')
plt.title('PDX Weather Predictions for 2016 vs 2015')
plt.legend(handles=[plot_predicted, plot_test])
plt.show()

# %%
print(np.sqrt(((predicted - y['test']) ** 2).mean(axis=0)))
# Out:
# [ 0.73725587  1.33070683]
